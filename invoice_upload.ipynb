# %%
# -*-coding:utf-8-*-
"""
处理xml格式财务数据
数据直接入发票表与交易表（单挑录入，录完后删掉已录入文件）
注意在main函数里修改筛选日期
"""
import pymysql
import os
from lxml import etree
import codecs
import re
import shutil


connection = pymysql.connect(host='39.105.9.20', user='root', passwd='bigdata_oil',
                db='cxd_data', port=3306, charset='utf8')
cursor = connection.cursor()


def xml_parse(com, path):
    try:
        data = etree.parse(path)
    except:
        try:
            #os.system("PowerShell -Command '& {get-content %s | set-content %s -encoding utf8}'" % (path, path))
            f = codecs.open(path, 'r', 'utf-8')
            content = f.read()  # 文本方式读入
            content = re.sub("GB2312", "UTF-8", content)  # 替换encoding头
            f.close()
            f = open(path, 'w')  # 写入
            f.write(content)
            f.close()
            data = etree.parse(path)
        except:
            try:
                #os.system("PowerShell -Command '& {get-content %s | set-content %s -encoding utf8}'" % (path, path))
                f = codecs.open(path, 'r', 'gbk')
                content = f.read()  # 文本方式读入
                content = re.sub("GB2312", "UTF-8", content)  # 替换encoding头
                f.close()
                f = open(path, 'w')  # 写入
                f.write(content)
                f.close()
                data = etree.parse(path)
            except Exception as e:
                print(str(e))
                print('文件问题')
                try:
                    copy_file(path, com)
                    #del_files(path)
                except FileExistsError:
                    return 0
                return 0

    record = []

    row_data = data.getroot()
    for row in row_data:
        for field in row:
            row = []
            fpdm = field.get('发票代码')
            fphm = field.get('发票号码')
            gfmc = field.get('客户名称')
            gfsh = field.get('客户识别号')
            spmc = field.get('主要商品名称')
            je = field.get('合计金额')
            se = field.get('税额')
            kj_name = field.get('开票人')
            jshj = field.get('价税合计')
            kprq = field.get('开票日期')
            row.append(fpdm)
            row.append(fphm)
            row.append(gfmc)
            row.append(gfsh)
            row.append(spmc)
            row.append(je)
            row.append(se)
            row.append(kprq)
            row.append(com)
            row.append(kj_name)
            record.append(row)
    return record


def xml_parse_other(com, path):
    """
    处理有单价xml文件
    :param com:
    :param path:
    :return:
    """
    xml = etree.parse(path)
    data = xml.getroot()
    fp_data = data.xpath('/Kp/Fpxx/Fpsj/Fp')
    reocrd = []
    for fp in fp_data:
        tmp = []
        Lbdm = fp.xpath('./Lbdm')[0].text
        Fphm = fp.xpath('./Fphm')[0].text
        Gfmc = fp.xpath('./Gfmc')[0].text
        Gfsh = fp.xpath('./Gfsh')[0].text
        Gfyhzh = fp.xpath('./Gfyhzh')[0].text
        Gfdzdh = fp.xpath('./Gfdzdh')[0].text
        Xfmc = fp.xpath('./Xfmc')[0].text
        Xfsh = fp.xpath('./Xfsh')[0].text
        Xfyhzh = fp.xpath('./Xfyhzh')[0].text
        Xfdzdh = fp.xpath('./Xfdzdh')[0].text
        Kprq = fp.xpath('./Kprq')[0].text
        Kpr = fp.xpath('./Kpr')[0].text
        Spmc = fp.xpath('./Spxx/Sph/Spmc')[0].text
        Jldw = fp.xpath('./Spxx/Sph/Jldw')[0].text
        Dj = fp.xpath('./Spxx/Sph/Dj')[0].text
        Sl = fp.xpath('./Spxx/Sph/Sl')[0].text
        Je = fp.xpath('./Spxx/Sph/Je')[0].text
        Slv = fp.xpath('./Spxx/Sph/Slv')[0].text
        Se = fp.xpath('./Spxx/Sph/Se')[0].text
        tmp.append(Lbdm)
        tmp.append(Fphm)
        tmp.append(Gfmc)
        tmp.append(Gfsh)
        tmp.append(Gfyhzh)
        tmp.append(Gfdzdh)
        tmp.append(Xfmc if Xfmc else com)
        tmp.append(Kprq)
        tmp.append(Kpr)
        tmp.append(Spmc)
        tmp.append(Jldw)
        tmp.append(round(float(Dj), 2))
        tmp.append(Sl)
        tmp.append(Je)
        tmp.append(Slv)
        tmp.append(Se)
        reocrd.append(tmp)
    return reocrd


docxlist = {}
com_name = ''


def gci(filepath):
    # 遍历filepath下所有文件，包括子目录
    global com_name
    files = os.listdir(filepath)
    for fi in files:
        if fi == '.DS_Store':
            continue
        fi_d = os.path.join(filepath, fi)
        if os.path.isdir(fi_d):
            if '公司' in fi:
                com_name = fi
                docxlist[com_name] = []
            gci(fi_d)
        else:
            docxlist[com_name].append(fi_d)
    return docxlist

def copy_file(path_ori, com): #将有问题的文件复制到另一个位置
    # base_dir = r'D:\Selvaria\scripts\company\changxing_invoice\有问题公司文件\SWXML\2019-11-25'
    if 'SWXML' in path_ori:
        new_path = './有问题公司文件'+path_ori[1:19]
    elif 'SWEXCEL' in path_ori:
        new_path = './有问题公司文件'+path_ori[1:21]
    elif 'XSZ' in path_ori:
        new_path = './有问题公司文件'+path_ori[1:17]
#     elif '购销' in path_ori:
#         new_path = './有问题公司文件'+path_ori[1:16]
    else: #XSZXLS
        new_path = './有问题公司文件'+path_ori[1:20]
        
    
    if os.path.isdir(new_path): 
        os.mkdir(os.path.join(new_path, com)) 
    else:
        print('建立文件夹的路径不存在')
    shutil.copy(path_ori, './有问题公司文件'+path_ori[1:]) #复制前后的位置
    print('复制完成:%s' %com)
    

def del_files(path):
    if os.path.exists(path):  # 如果文件存在
        os.remove(path)  
        print('已删除：',path)
    else:
        print('no such file:'%path)


if __name__ == "__main__":
    path_list = gci('./二次导入')
    # print(path_list)
    xml = []
    excel = []
    for k, v in path_list.items():
        if not v:
            continue
        for path in v:
            if 'xml' in path:
                xml.append([k, path])
            else:
                excel.append([k, path])

    # 发票表入库sql
    bill_sql = "INSERT INTO ticket_bill (Lbdm,Fphm,Gfmc,Gfsh,Spmc,Je,Se,Kprq,Xfmc,kj_name) " \
               "VALUES (%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)"
    bill_sql_other = "INSERT INTO ticket_bill (Lbdm,Fphm,Gfmc,Gfsh,Gfyhzh,Gfdzdh,Xfmc,Kprq,kj_name,Spmc," \
                     "Jldw,Dj,Sl,Je,Slv,Se) VALUES (%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)"
    # 交易表入库sql
    trade_sql = "INSERT INTO financial_exchange (Gf_company_name,exchange_good,Je,exchange_date,Xf_company_name) " \
                "VALUES (%s,%s,%s,%s,%s)"
    trade_sql_other = "INSERT INTO financial_exchange (Gf_company_name,Xf_company_name,exchange_date,exchange_good," \
                      "Jldw,Dj,Sl,Je) VALUES (%s,%s,%s,%s,%s,%s,%s,%s)"

    for r in xml:
        print(r[0])
        print(r[1])
#         if len(r[1]) == 0:
#             continue
        res = xml_parse(r[0], r[1])
    
        if res == 0: #无法解析文件
            continue
            
        if res[0][0] is None:
            res = xml_parse_other(r[0], r[1])
            #print(res[0][7])
            try:
                check_time = int(res[0][7].translate(str.maketrans('', '', '-')))
                if check_time > 20190501:  # 按需要筛选时间
                    cursor.executemany(bill_sql_other, res)
            except:
                try:
                    check_time = int(res[0][7][:8])
                    if check_time > 20190501:  # 按需要筛选时间
                        cursor.executemany(bill_sql_other, res)
                except:
                    pass
            
            # 处理入交易表数据
            trade_data = []
            
            for info in res:

                try:
                    check_time = int(res[0][7].translate(str.maketrans('', '', '-')))
                except:
                    check_time = int(res[0][7][:8])
                if check_time < 20190501:  # 按需要筛选时间
                    continue

                tmp = [info[2], info[6], info[7], info[9], info[10], info[11], info[12], info[13]]
                trade_data.append(tmp)
            cursor.executemany(trade_sql_other, trade_data)
        else:
            bill_data=[]
            for info in res:
                try:
                    check_time = int(res[0][7].translate(str.maketrans('', '', '-')))
                except:
                    check_time = int(res[0][7][:8])
                if check_time < 20190501:
                    continue# 按需要筛选时间
                bill_data.append(info)
                cursor.executemany(bill_sql, bill_data)

            # 处理入交易表数据
            trade_data = []
            for info in res:

                try:
                    check_time = int(res[0][7].translate(str.maketrans('', '', '-')))
                except:
                    check_time = int(res[0][7][:8])
                if check_time < 20190501:  # 按需要筛选时间
                    continue

                tmp = [info[2], info[4], info[5], info[7], info[8]]
                trade_data.append(tmp)
            cursor.executemany(trade_sql, trade_data)
        connection.commit()
        try:
            del_files(r[1])
        except Exception as e:
            print(str(e))
            continue
# Out:
# 大连方舟石油化工有限公司
# ./二次导入\SWEXCEL\SWEXCEL\2019-11-22\大连方舟石油化工有限公司\ad4f0a44-8469-45a5-b207-b37ebfe871d0_已开发票191122_104656方舟.xml
# 已删除： ./二次导入\SWEXCEL\SWEXCEL\2019-11-22\大连方舟石油化工有限公司\ad4f0a44-8469-45a5-b207-b37ebfe871d0_已开发票191122_104656方舟.xml
# 中油华铁能源科技（大连）有限公司
# ./二次导入\SWEXCEL\SWEXCEL\2019-11-25\中油华铁能源科技（大连）有限公司\d41296ef-a76c-49cb-b32b-c570e6a1d556_已开发票191122_101749.xml
# 已删除： ./二次导入\SWEXCEL\SWEXCEL\2019-11-25\中油华铁能源科技（大连）有限公司\d41296ef-a76c-49cb-b32b-c570e6a1d556_已开发票191122_101749.xml
# 中油双龙（大连）石油化工有限公司
# ./二次导入\SWEXCEL\SWEXCEL\2019-11-25\中油双龙（大连）石油化工有限公司\ef5d7e97-690c-48bf-b6a8-8838906550eb_已开发票191122_185229双龙.xml
# 已删除： ./二次导入\SWEXCEL\SWEXCEL\2019-11-25\中油双龙（大连）石油化工有限公司\ef5d7e97-690c-48bf-b6a8-8838906550eb_已开发票191122_185229双龙.xml
# 中融致远能源（大连）有限公司
# ./二次导入\SWEXCEL\SWEXCEL\2019-11-25\中融致远能源（大连）有限公司\f4e01f4f-65e3-4fd0-ac69-4193d71fd0f8_已开发票191122_103731.xml
# 已删除： ./二次导入\SWEXCEL\SWEXCEL\2019-11-25\中融致远能源（大连）有限公司\f4e01f4f-65e3-4fd0-ac69-4193d71fd0f8_已开发票191122_103731.xml
# 大连中油锦泰石油化工有限公司
# ./二次导入\SWEXCEL\SWEXCEL\2019-11-25\大连中油锦泰石油化工有限公司\f4f19b4a-1032-4400-88aa-0e5f01dba5ce_专票和普票.xml
# 已删除： ./二次导入\SWEXCEL\SWEXCEL\2019-11-25\大连中油锦泰石油化工有限公司\f4f19b4a-1032-4400-88aa-0e5f01dba5ce_专票和普票.xml
# 大连宝启能源有限公司
# ./二次导入\SWEXCEL\SWEXCEL\2019-11-25\大连宝启能源有限公司\a77ba09c-a661-428c-960e-eebaf41e75c7_已开发票191122_105259.xml
# 已删除： ./二次导入\SWEXCEL\SWEXCEL\2019-11-25
xml
# 已删除： ./二次导入\SWXML\SWXML\2019-11-26\大连裕泰石油化工有限公司\631b25ea-cab0-4b86-b7f1-6fd4ad871a09_裕泰已开发票191125_122702.xml
# 大连金东升石油销售有限公司
# ./二次导入\SWXML\SWXML\2019-11-26\大连金东升石油销售有限公司\53523f5d-7892-44c3-8c18-97e6fb93148d_金东升专普.xml
# 已删除： ./二次导入\SWXML\SWXML\2019-11-26\大连金东升石油销售有限公司\53523f5d-7892-44c3-8c18-97e6fb93148d_金东升专普.xml
# 大连金文汇创石油化工有限公司
# ./二次导入\SWXML\SWXML\2019-11-26\大连金文汇创石油化工有限公司\c360cbf4-1564-48a3-bf49-eb230acbf231_金文已开发票191122_151009.xml
# 已删除： ./二次导入\SWXML\SWXML\2019-11-26\大连金文汇创石油化工有限公司\c360cbf4-1564-48a3-bf49-eb230acbf231_金文已开发票191122_151009.xml
# 新中石化（大连）有限公司
# ./二次导入\SWXML\SWXML\2019-11-26\新中石化（大连）有限公司\0e8a974d-137d-4df0-a9b5-c56d06b6191c_已开发票191125_155524新中石化电子.xml
# 已删除： ./二次导入\SWXML\SWXML\2019-11-26\新中石化（大连）有限公司\0e8a974d-137d-4df0-a9b5-c56d06b6191c_已开发票191125_155524新中石化电子.xml
# 申博石化（大连）有限公司
# ./二次导入\SWXML\SWXML\2019-11-26\申博石化（大连）有限公司\41fddfac-52bc-47a4-a787-37f187fe53a4_申博已开发票191126_133116.xml
# 已删除： ./二次导入\SWXML\SWXML\2019-11-26\申博石化（大连）有限公司\41fddfac-52bc-47a4-a787-37f187fe53a4_申博已开发票191126_133116.xml
# 金汇石油化工（大连）有限公司
# ./二次导入\SWXML\SWXML\2019-11-26\金汇石油化工（大连）有限公司\1c037de4-73e5-4ab9-8099-dede1602f7d6_金汇专普.xml
# 已删除： ./二次导入\SWXML\SWXML\2019-11-26\金汇石油化工（大连）有限公司\1c037de4-73e5-4ab9-8099-dede1602f7d6_金汇专普.xml
# 大连国和诚宇石油化工有限公司
# ./二次导入\XSZ\XSZ\2019-11-25\大连国和诚宇石油化工有限公司\0d284f1e-06bd-44b2-887f-c4bfe2ea6533_国和诚宇已开发票191125_100719.xml
# 已删除： ./二次导入\XSZ\XSZ\2019-11-25\大连国和诚宇石油化工有限公司\0d284f1e-06bd-44b2-887f-c4bfe2ea6533_国和诚宇已开发票191125_100719.xml
# 大连运起石化有限公司
# ./二次导入\XSZ\XSZ\2019-11-25\大连运起石化有限公司\d64dbc87-575e-4ac1-b37b-4e7c699440da_运起.xml
# 已删除： ./二次导入\XSZ\XSZ\2019-11-25\大连运起石化有限公司\d64dbc87-575e-4ac1-b37b-4e7c699440da_运起.xml

# %%
l = [['铁岭市清河区张相镇人民政府', '2019-10-23', '*建筑服务*锅炉安装', '', '', '', '72477.06', '蒲思坤环保工程（大连）有限公司'], \
     ['铁岭市清河区张相镇人民政府', '2019-10-23', '*建筑服务*锅炉安装', '', '', '', '72477.06', '蒲思坤环保工程（大连）有限公司']]
l
# Out:
# [['铁岭市清河区张相镇人民政府',
#   '2019-10-23',
#   '*建筑服务*锅炉安装',
#   '',
#   '',
#   '',
#   '72477.06',
#   '蒲思坤环保工程（大连）有限公司'],
#  ['铁岭市清河区张相镇人民政府',
#   '2019-10-23',
#   '*建筑服务*锅炉安装',
#   '',
#   '',
#   '',
#   '72477.06',
#   '蒲思坤环保工程（大连）有限公司']]

# %%
s = l[0][-4]
print(type(s))
float(s)
# Out:
# <class 'str'>
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-43-ab9645843595> in <module>()
#       1 s = l[0][-4]
#       2 print(type(s))
# ----> 3 float(s)
#
# ValueError: could not convert string to float:
