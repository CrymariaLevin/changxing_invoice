# %%
# -*-coding:utf-8-*-
"""
处理excel财务数据
数据直接入发票表与交易表
注意在main函数里有时间筛选
"""
import pymysql
import os
import xlrd

connection = pymysql.connect(host='39.105.9.20', user='root', passwd='bigdata_oil',
                db='cxd_data', port=3306, charset='utf8')
cursor = connection.cursor()


def read_xls(path, flag=0):
    record = []
    data = xlrd.open_workbook(path, encoding_override="cp1252")  # 打开xls文件
    table = data.sheets()[0]  # 打开第一张表
    nrows = table.nrows  # 获取表的行数
    if flag == 0:
        for i in range(nrows):
            if i < 4:  # 跳过前4行
                continue
            record.append(table.row_values(i))
    else:
        for i in range(nrows):
            if i < 6:  # 跳过前6行
                continue
            record.append(table.row_values(i))
    return record


docxlist = {}
com_name = ''




def gci(filepath):
    # 遍历filepath下所有文件，包括子目录
    global com_name
    files = os.listdir(filepath)
    for fi in files:
        if fi == '.DS_Store':
            continue
        fi_d = os.path.join(filepath, fi)
        if os.path.isdir(fi_d):
            if '公司' in fi:
                com_name = fi
                docxlist[com_name] = []
            gci(fi_d)
        else:
            docxlist[com_name].append(fi_d)
    return docxlist


def parse_data(com, info_data):
    """
    发票1：
    ['0发票代码', '1发票号码', '2购方企业名称', '3购方税号', '4银行帐号', '5地址电话', '6开票日期',
    '7商品编码版本号', '8单据号', '9商品名称', '10规格',
    '11单位', '12数量', '13单价', '14金额', '15税率', '16税额', '17税收分类编码']
    发票2：
    ['0发票代码', '1发票号码', '2购方企业名称', '3购方税号', '4银行帐号', '5地址电话', '6开票日期',
    '7单据号', '8备注', '9商品名称', '10规格', '11单位', '12数量', '13单价', '14金额', '15税率', '16税额', '17发票状态']
    :param com:
    :param info_data:
    :return:
    """
    record = []
    Xfmc = com

    for fp_info in info_data:
        if '小计' in fp_info or '份数' in fp_info[0]:
            continue
        if fp_info[0] != '':
            Lbdm = fp_info[0]
            Fphm = fp_info[1]
            Gfmc = fp_info[2]
            Gfsh = fp_info[3]
            Gfyhzh = fp_info[4]
            Gfdzdh = fp_info[5]
            Kprq = fp_info[6][:10]
            Spmc = fp_info[9]
            Ggxh = fp_info[10]
            Jldw = fp_info[11]
            Sl = fp_info[12]
            Dj = fp_info[13]
            Je = fp_info[14]
            Slv = fp_info[15]
            Se = fp_info[16]
        else:
            Spmc = fp_info[9]
            Ggxh = fp_info[10]
            Jldw = fp_info[11]
            Sl = fp_info[12]
            Dj = fp_info[13]
            Je = fp_info[14]
            Slv = fp_info[15]
            Se = fp_info[16]
        record.append([Lbdm, Fphm, Gfmc, Gfsh, Gfyhzh, Gfdzdh,
                       Kprq, Spmc, Ggxh, Jldw, Sl, Dj, Je, Slv, Se, Xfmc])
    return record

def del_files(path):
    if os.path.exists(path):  # 如果文件存在
        os.remove(path)  
        print('已删除：',path)
    else:
        print('no such file:'%path)


if __name__ == "__main__":
    path_list = gci('./SWEXCEL')
    xml = []
    excel = []
    excel_other = []
    for k, v in path_list.items():
        # print(k, v)
        if not v:
            continue
        for path in v:
            if '序时' in path or '余额' in path:
                continue
            if 'xml' in path:
                xml.append([k, path])
            else:
                if 'xls' not in path and 'xlsx' not in path:
                    continue
                if 'xlsx' in path or '明细' in path:
                    excel_other.append([k, path])
                else:
                    excel.append([k, path])

    # 发票表入库sql
    bill_sql = "INSERT INTO ticket_bill (Lbdm,Fphm,Gfmc,Gfsh,Gfyhzh,Gfdzdh,Kprq,Spmc,Ggxh,Jldw,Sl,Dj,Je,Slv,Se,Xfmc) " \
               "VALUES (%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)"
    # 交易表入库sql
    trade_sql = "INSERT INTO financial_exchange (Gf_company_name,exchange_date,exchange_good,Jldw,Sl,Dj,Je," \
                "Xf_company_name) VALUES (%s,%s,%s,%s,%s,%s,%s,%s)"

    for r in excel:
        print(r[1])
        fp_data = read_xls(r[1])
        try:
            fp = parse_data(r[0], fp_data)
        except:
            print(r[1])
            break
        # cursor.executemany(bill_sql, fp)
        # 处理入交易表数据
        trade_data = []
        for info in fp:
            check_time = int(info[6].translate(str.maketrans('', '', '-')))
            if check_time < 20190501: # 按需要筛选时间
                continue
            tmp = [info[2], info[6], info[7], info[9], info[10], info[11], info[12], info[15]]
            trade_data.append(tmp)
        cursor.executemany(trade_sql, trade_data)
        connection.commit()

    for r in excel_other:
        print(r[1])
        fp_data = read_xls(r[1], 1)
        #print(r[1])
        try:
            fp = parse_data(r[0], fp_data)
        except Exception as e:
            print('问题文件：', r[1])
            print(str(e))
            break
        # cursor.executemany(bill_sql, fp)
        # 处理入交易表数据
        trade_data = []
        for info in fp:
            check_time = int(info[6].translate(str.maketrans('', '', '-')))
            if check_time < 20190501:  # 按需要筛选时间
                continue
            tmp = [info[2], info[6], info[7], info[9], info[10], info[11], info[12], info[15]]
            trade_data.append(tmp)
        cursor.executemany(trade_sql, trade_data)
        connection.commit()
# Out:
# ./SWEXCEL\2019-11-22\中油丰泰能源（大连）有限公司\905ee65f-c02f-46a0-bcd3-3e5bf4b217dd_丰泰专.xls
# ./SWEXCEL\2019-11-22\中油千溪能源（大连）有限责任公司\a9f2eb29-e072-4ede-ad71-1e773949b08e_千溪专.xls
# ./SWEXCEL\2019-11-22\中油华中能源（大连）有限公司\26c31eb2-a5f1-4e52-9562-555530206ab6_华中专.xls
# ./SWEXCEL\2019-11-22\中油天宏能源（大连）有限公司\d6dcc3b3-0fd4-4fd6-a29d-df9c9df0e409_天宏专.xls
# ./SWEXCEL\2019-11-22\中油晋闻（大连）石油化工有限公司\9861ad9b-4044-4e9c-a413-eb144ef109e5_晋闻普.xls
# ./SWEXCEL\2019-11-25\中化正飞国际贸易（大连）有限公司\6d3fda91-64d4-4480-a5b5-0bc84c21b440_专票.xls
# ./SWEXCEL\2019-11-25\中化海洋能源（大连）有限公司\0728acfd-b29d-4f04-8d33-28ee245ea6b8_专票.xls
# ./SWEXCEL\2019-11-25\中化胜隆石油化工（大连）有限公司\ece806b7-6e69-4d74-8191-f8d9667d4e01_专票.xls
# ./SWEXCEL\2019-11-25\中油万泉（大连）石化有限公司\b8232e00-fb8f-4b78-af99-8e66a17444e0_专票.xls
# ./SWEXCEL\2019-11-25\中油东成石油化工（大连）有限公司\34f74ee4-9e76-438e-ae49-27efcd946d98_专票.xls
# ./SWEXCEL\2019-11-25\中油东成石油化工（大连）有限公司\71b6d28c-410c-4f97-9fe3-f97ae794135e_专票.xls
# ./SWEXCEL\2019-11-25\中油东成石油化工（大连）有限公司\96dffef4-2d08-4bb2-bb96-ac4736a21cdb_普票.xls
# ./SWEXCEL\2019-11-25\中油东成石油化工（大连）有限公司\ecc5140f-84e5-4c0a-9e59-c727132b7eaf_普票.xls
# ./SWEXCEL\2019-11-25\中油中睿（大连）石化有限公司\be480ddd-2ef1-441f-b810-49cf8ca47966_专票.xls
# ./SWEXCEL\2019-11-25\中油佳瑞（大连）石油化工有限公司\ad8947f3-a058-4948-a1fd-60174cd8b1e3_佳瑞2019大数据专票.xls
# ./SWEXCEL\2019-11-25\中油加仑多石化（大连）有限公司\36da100b-0a1d-414e-8779-6443757e934f_普票.xls
# ./SWEXCEL\2019-11-25\中油加仑多石化（大连）有限公司\f6c10680-8e30-4dcf-a6f5-5008b0b60277_专票.xls
# ---------------------------------------------------------------------------
# DataError                                 Traceback (most recent call last)
# <ipython-input-6-958a58aa8864> in <module>()
#     156             tmp = [info[2], info[6], info[7], info[9], info[10], info[11], info[12], info[15]]
#     157             trade_data.append(tmp)
# --> 158         cursor.executemany(trade_sql, trade_data)
#     159         connection.commit()
#     160
#
# D:\Selvaria\Anaconda\lib\site-packages\pymysql\cursors.py in executemany(self, query, args)
#     190             return self._do_execute_many(q_prefix, q_values, q_postfix, args,
#     191                                          self.max_stmt_length,
# --> 192                                          self._get_db().encoding)
#     193
#     194         self.rowcount = sum(self.execute(query, arg) for arg in args)
#
# D:\Selvaria\Anaconda\lib\site-packages\pymysql\cursors.py in _do_execute_many(self, prefix, values, postfix, args, max_stmt_length, encoding)
#     227                 sql += b','
#     228             sql += v
# --> 229         rows += self.execute(sql + postfix)
#     230         self.rowcount = rows
#     231         return rows
#
# D:\Selvaria\Anaconda\lib\site-packages\pymysql\cursors.py in execute(self, query, args)
#     163         query = self.mogrify(query, args)
#     164
# --> 165         result = self._query(query)
#     166         self._executed = query
#     167         return result
#
# D:\Selvaria\Anaconda\lib\site-packages\pymysql\cursors.py in _query(self, q)
#     319         conn = self._get_db()
#     320         self._last_executed = q
# --> 321         conn.query(q)
#     322         self._do_get_result()
#     323         return self.rowcount
#
# D:\Selvaria\Anaconda\lib\site-packages\pymysql\connections.py in query(self, sql, unbuffered)
#     858                 sql = sql.encode(self.encoding, 'surrogateescape')
#     859         self._execute_command(COMMAND.COM_QUERY, sql)
# --> 860         self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     861         return self._affected_rows
#     862
#
# D:\Selvaria\Anaconda\lib\site-packages\pymysql\connections.py in _read_query_result(self, unbuffered)
#    1059         else:
#    1060             result = MySQLResult(self)
# -> 1061             result.read()
#    1062         self._result = result
#    1063         if result.server_status is not None:
#
# D:\Selvaria\Anaconda\lib\site-packages\pymysql\connections.py in read(self)
#    1347     def read(self):
#    1348         try:
# -> 1349             first_packet = self.connection._read_packet()
#    1350
#    1351             if first_packet.is_ok_packet():
#
# D:\Selvaria\Anaconda\lib\site-packages\pymysql\connections.py in _read_packet(self, packet_type)
#    1016
#    1017         packet = packet_type(buff, self.encoding)
# -> 1018         packet.check_error()
#    1019         return packet
#    1020
#
# D:\Selvaria\Anaconda\lib\site-packages\pymysql\connections.py in check_error(self)
#     382             errno = self.read_uint16()
#     383             if DEBUG: print("errno =", errno)
# --> 384             err.raise_mysql_exception(self._data)
#     385
#     386     def dump(self):
#
# D:\Selvaria\Anaconda\lib\site-packages\pymysql\err.py in raise_mysql_exception(data)
#     105         errval = data[3:].decode('utf-8', 'replace')
#     106     errorclass = error_map.get(errno, InternalError)
# --> 107     raise errorclass(errno, errval)
#
# DataError: (1265, "Data truncated for column 'Sl' at row 26")
